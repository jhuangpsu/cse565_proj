# %%
from graph import *
from graph_helper import *
from graph_generator import *
from constants import *
from collections import deque
from input_output import *
from random import shuffle, randint

# %%
construction_type = RANDOM
leafy_tree, hard_graph = create_hard_tree_and_graph(construction_type)

# %%
leafy_tree

# %%
plot_graph(leafy_tree)

# %%
file_name = 'demo.txt'
output_graphs_to_new_file(leafy_tree, file_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zx/815xrstn0s3ccx896grmh6z80000gn/T/ipykernel_7043/1845243532.py in <module>
#       1 file_name = 'demo.txt'
# ----> 2 output_graphs_to_new_file(leafy_tree, file_name)
#
# ~/PSU/CSE 565/project/maximum_leaf_spanning_tree/python/input_output.py in output_graphs_to_new_file(graphs, file_name)
#      58         output_file.write(str(1) + '\n')
#      59
# ---> 60         for graph in graphs:
#      61                 output_graph_to_existing_file(graph, output_file)
#      62
#
# TypeError: 'Graph' object is not iterable
